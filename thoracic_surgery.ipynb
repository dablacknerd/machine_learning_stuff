# %%
import pandas as pd
thoracic_df = pd.read_csv("C:\\Users\\aoguntuga\\Documents\\DataSets\\thoracic.csv", sep =',',
                          index_col=False,
                          names=['Diagnosis','FVC','FEV1','Zubrod scale',
                                   'Pain before surgery','Haemoptysis before surgery','Dyspnoea before surgery',
                                   'Cough before surgery','Weakness before surgery','T in clinical TNM','Type 2 DM',
                                   'MI up to 6 months','PAD','Smoking','Asthma','Age at surgery','1 year survival period']
                         )

# %%
thoracic_df.head()
# Out:
#   Diagnosis   FVC  FEV1 Zubrod scale Pain before surgery  \
# 0      DGN2  2.88  2.16         PRZ1                   F
# 1      DGN3  3.40  1.88         PRZ0                   F
# 2      DGN3  2.76  2.08         PRZ1                   F
# 3      DGN3  3.68  3.04         PRZ0                   F
# 4      DGN3  2.44  0.96         PRZ2                   F
#
#   Haemoptysis before surgery Dyspnoea before surgery Cough before surgery  \
# 0                          F                       F                    T
# 1                          F                       F                    F
# 2                          F                       F                    T
# 3                          F                       F                    F
# 4                          T                       F                    T
#
#   Weakness before surgery T in clinical TNM Type 2 DM MI up to 6 months PAD  \
# 0                       T              OC14         F                 F   F
# 1                       F              OC12         F                 F   F
# 2                       F              OC11         F                 F   F
# 3                       F              OC11         F                 F   F
# 4                       T              OC11         F                 F   F
#
#   Smoking Asthma  Age at surgery 1 year survival period
# 0       T      F              60                      F
# 1       T      F              51                      F
# 2       T      F              59                      F
# 3       F      F              54                      F
# 4       T      F              73                      T

# %%
d1 = {'F':0, 'T':1}
d2 = {'PRZ2': 2,'PRZ1':1,'PRZ0':0}
d3 = {'DGN3':3,'DGN2':2,'DGN4':4,'DGN6':6,'DGN5':5,'DGN8':8,'DGN1':1,'DGN7':7}
d4 = {'OC11':1,'OC12':2,'OC13':3,'OC14':4}
thoracic_df['Diagnosis'] = thoracic_df['Diagnosis'].map(d3)
thoracic_df['Zubrod scale'] = thoracic_df['Zubrod scale'].map(d2)
thoracic_df['T in clinical TNM'] = thoracic_df['T in clinical TNM'].map(d4)

thoracic_df.head()
# Out:
#    Diagnosis   FVC  FEV1  Zubrod scale Pain before surgery  \
# 0          2  2.88  2.16             1                   F
# 1          3  3.40  1.88             0                   F
# 2          3  2.76  2.08             1                   F
# 3          3  3.68  3.04             0                   F
# 4          3  2.44  0.96             2                   F
#
#   Haemoptysis before surgery Dyspnoea before surgery Cough before surgery  \
# 0                          F                       F                    T
# 1                          F                       F                    F
# 2                          F                       F                    T
# 3                          F                       F                    F
# 4                          T                       F                    T
#
#   Weakness before surgery  T in clinical TNM Type 2 DM MI up to 6 months PAD  \
# 0                       T                  4         F                 F   F
# 1                       F                  2         F                 F   F
# 2                       F                  1         F                 F   F
# 3                       F                  1         F                 F   F
# 4                       T                  1         F                 F   F
#
#   Smoking Asthma  Age at surgery 1 year survival period
# 0       T      F              60                      F
# 1       T      F              51                      F
# 2       T      F              59                      F
# 3       F      F              54                      F
# 4       T      F              73                      T

# %%
thoracic_df['Asthma'] = thoracic_df['Asthma'].map(d1)
thoracic_df['PAD'] = thoracic_df['PAD'].map(d1)
thoracic_df['Smoking'] = thoracic_df['Smoking'].map(d1)

thoracic_df.head()
# Out:
#    Diagnosis   FVC  FEV1  Zubrod scale Pain before surgery  \
# 0          2  2.88  2.16             1                   F
# 1          3  3.40  1.88             0                   F
# 2          3  2.76  2.08             1                   F
# 3          3  3.68  3.04             0                   F
# 4          3  2.44  0.96             2                   F
#
#   Haemoptysis before surgery Dyspnoea before surgery Cough before surgery  \
# 0                          F                       F                    T
# 1                          F                       F                    F
# 2                          F                       F                    T
# 3                          F                       F                    F
# 4                          T                       F                    T
#
#   Weakness before surgery  T in clinical TNM Type 2 DM MI up to 6 months  PAD  \
# 0                       T                  4         F                 F    0
# 1                       F                  2         F                 F    0
# 2                       F                  1         F                 F    0
# 3                       F                  1         F                 F    0
# 4                       T                  1         F                 F    0
#
#    Smoking  Asthma  Age at surgery 1 year survival period
# 0        1       0              60                      F
# 1        1       0              51                      F
# 2        1       0              59                      F
# 3        0       0              54                      F
# 4        1       0              73                      T

# %%
thoracic_df['Cough before surgery'] = thoracic_df['Cough before surgery'].map(d1)
thoracic_df['Weakness before surgery'] = thoracic_df['Weakness before surgery'].map(d1)
thoracic_df['Dyspnoea before surgery'] = thoracic_df['Dyspnoea before surgery'].map(d1)
thoracic_df['Haemoptysis before surgery'] = thoracic_df['Haemoptysis before surgery'].map(d1)

thoracic_df.head()
# Out:
#    Diagnosis   FVC  FEV1  Zubrod scale Pain before surgery  \
# 0          2  2.88  2.16             1                   F
# 1          3  3.40  1.88             0                   F
# 2          3  2.76  2.08             1                   F
# 3          3  3.68  3.04             0                   F
# 4          3  2.44  0.96             2                   F
#
#    Haemoptysis before surgery  Dyspnoea before surgery  Cough before surgery  \
# 0                           0                        0                     1
# 1                           0                        0                     0
# 2                           0                        0                     1
# 3                           0                        0                     0
# 4                           1                        0                     1
#
#    Weakness before surgery  T in clinical TNM Type 2 DM MI up to 6 months  \
# 0                        1                  4         F                 F
# 1                        0                  2         F                 F
# 2                        0                  1         F                 F
# 3                        0                  1         F                 F
# 4                        1                  1         F                 F
#
#    PAD  Smoking  Asthma  Age at surgery 1 year survival period
# 0    0        1       0              60                      F
# 1    0        1       0              51                      F
# 2    0        1       0              59                      F
# 3    0        0       0              54                      F
# 4    0        1       0              73                      T

# %%
thoracic_df['Pain before surgery'] = thoracic_df['Pain before surgery'].map(d1)
thoracic_df['Type 2 DM'] = thoracic_df['Type 2 DM'].map(d1)
thoracic_df['MI up to 6 months'] = thoracic_df['MI up to 6 months'].map(d1)
thoracic_df['1 year survival period'] = thoracic_df['1 year survival period'].map(d1)

thoracic_df.head()
# Out:
#    Diagnosis   FVC  FEV1  Zubrod scale  Pain before surgery  \
# 0          2  2.88  2.16             1                    0
# 1          3  3.40  1.88             0                    0
# 2          3  2.76  2.08             1                    0
# 3          3  3.68  3.04             0                    0
# 4          3  2.44  0.96             2                    0
#
#    Haemoptysis before surgery  Dyspnoea before surgery  Cough before surgery  \
# 0                           0                        0                     1
# 1                           0                        0                     0
# 2                           0                        0                     1
# 3                           0                        0                     0
# 4                           1                        0                     1
#
#    Weakness before surgery  T in clinical TNM  Type 2 DM  MI up to 6 months  \
# 0                        1                  4          0                  0
# 1                        0                  2          0                  0
# 2                        0                  1          0                  0
# 3                        0                  1          0                  0
# 4                        1                  1          0                  0
#
#    PAD  Smoking  Asthma  Age at surgery  1 year survival period
# 0    0        1       0              60                       0
# 1    0        1       0              51                       0
# 2    0        1       0              59                       0
# 3    0        0       0              54                       0
# 4    0        1       0              73                       1

# %%
len(thoracic_df.index)
# Out:
# 470

# %%
df_train = thoracic_df[0:400].copy()
df_test = thoracic_df[400:].copy()

# %%
print len(df_train.index)
print len(df_test.index)
# Out:
# 400
# 70

# %%
len(df_train.columns)
# Out:
# 17

# %%
features = list(df_train.columns[0:16])
print features
# Out:
# ['Diagnosis', 'FVC', 'FEV1', 'Zubrod scale', 'Pain before surgery', 'Haemoptysis before surgery', 'Dyspnoea before surgery', 'Cough before surgery', 'Weakness before surgery', 'T in clinical TNM', 'Type 2 DM', 'MI up to 6 months', 'PAD', 'Smoking', 'Asthma', 'Age at surgery']

# %%
from sklearn.tree import DecisionTreeClassifier

X = df_train[features]
y = df_train['1 year survival period']

# %%
descisionModel = DecisionTreeClassifier().fit(X,y)

# %%
import numpy as np

test_data = df_test[features].head().as_matrix()
#df_test.head(10)
test_data[0]
# Out:
# 3.0

# %%
list_of_pats =[]
for row in test_data:
    list_of_pats.append(list(row))

# %%
#list_of_pats

print descisionModel.predict(list_of_pats)
# Out:
# [0 0 0 0 0]

# %%
df_test.head()
# Out:
#      Diagnosis   FVC  FEV1  Zubrod scale  Pain before surgery  \
# 400          3  2.48  1.60             0                    0
# 401          3  3.56  2.80             0                    0
# 402          3  2.96  2.20             1                    0
# 403          3  4.04  2.56             1                    0
# 404          2  2.96  2.24             0                    0
#
#      Haemoptysis before surgery  Dyspnoea before surgery  \
# 400                           0                        0
# 401                           0                        0
# 402                           0                        0
# 403                           1                        0
# 404                           0                        0
#
#      Cough before surgery  Weakness before surgery  T in clinical TNM  \
# 400                     0                        0                  1
# 401                     0                        0                  2
# 402                     1                        0                  2
# 403                     1                        0                  2
# 404                     1                        0                  2
#
#      Type 2 DM  MI up to 6 months  PAD  Smoking  Asthma  Age at surgery  \
# 400          0                  0    0        0       0              61
# 401          0                  0    0        0       0              69
# 402          0                  0    0        1       0              53
# 403          0                  0    0        1       0              55
# 404          0                  0    0        1       0              57
#
#      1 year survival period
# 400                       0
# 401                       0
# 402                       0
# 403                       0
# 404                       1

# %%
from sklearn.ensemble import RandomForestClassifier

decision_model_2 = RandomForestClassifier(n_estimators = 15)
decision_model_2.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=15, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
print decision_model_2.predict(list_of_pats)
# Out:
# [0 0 0 0 0]
